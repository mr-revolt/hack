# %% [markdown]
# ## requrst headers

# %%
"""headers = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36"}"""
# Out:
# 'headers = {"user-agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36"}'

# %% [markdown]
# Example:
# - `r = requests.get(url, headers=headers)`

# %%
import requests 
url = 'https://so.youku.com/search_video/q_hello'
cookies = dict(cookies_are='gray_mark=86; juid=01d6mqd0ubk4f; __ysuid=1553396568117aP0; cna=0/8cFePjpCQCARdp39NLcFjn; _uab_collina=155617887797857613766276; __ayft=1556452693566; __aysid=1556452693567WU5; __ayscnt=1; ctoken=XTBH9RkUF5FQi0z6VR1fCZ9I; ycid=0; P_ck_ctl=0864567149C381AD1AB1E00688107277; __arpvid=1556521199587D55JnG-1556521199612; __aypstp=25; __ayspstp=25; _m_h5_tk=30683b16362c7403b397e9a012ea57fe_1556524980021; _m_h5_tk_enc=eb322f6cc51e76f7b1ac210dd3d83baf; seid=01d9ju9b982uc2; referhost=; seidtimeout=1556523000938; ypvid=15565212009412GuNU4; yseid=1556521200943a7yrUz; ysestep=1; yseidcount=4; yseidtimeout=1556528400944; ystep=9; __ayvstp=9; __aysvstp=9; isg=BNzcanU97CkQTJgllZAVbMrorfqQ3gd4w-tq_rbfjkeqAX2L3mfYDxfzYQlcibjX')
res = requests.get(url, cookies=cookies)
content = res.text
content
# Out:
# '\r\n<!DOCTYPE html>\n<html>\n<head>\n  <meta name="data-spm" content="a2h0k">\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n  <meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n  <meta name="renderer" content="webkit" />\n  <meta charset="UTF-8" />\n  <title>hello</title>\n  <meta itemprop="keywords" name="keywords" content="hello"/>\n  <meta itemprop="description" name="description" content="hello" />  \n  <meta name="google-site-verification" content="F2zYXuMVH2X76NeYEdAiGokv0QFtgOB1ZgCSZPglQbs" />\n  <meta name="aplus-auto-exp"\n  content=\'[{"logkey":"/soku/exp","tag":"div","filter":"data-exp","pkgSize":9,"method":"GET"}]\'>\n  <link rel="stylesheet" href="//g.alicdn.com/youku-node/pc-sokupage/1.1.16/styles/soku/search.min.css">\n  <script src="//g.alicdn.com/ku/bigview.runtime/1.1.4/bigview.runtime.min.js"></script>\n</head>\n<body  data-spm="11417342"><script>\nwith(document)with(body)with(insertBefore(createElement("script"),firstChild))setAt
# ...

# %% [markdown]
# ### 超时的处理

# %%
requests.get('https://github.com/', timeout=0.001)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/miniconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/miniconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ...
